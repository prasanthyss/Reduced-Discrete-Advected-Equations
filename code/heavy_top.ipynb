# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from ipywidgets import interact, IntSlider, FloatSlider, fixed
from matplotlib import animation, rc
from IPython.display import HTML, Image
from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import proj3d
from math import sin, cos, pi

# %%
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')

# %% [markdown]
# ## Define Integrator & helper functions
#
# ### Variational Integrator
#
# We  assume here that gravity is opposite Z-direction

# %%
def VI(R, Π, f, J, ρ, m, eps, h):      # Π, f, ρ are column vectors
    
    M_prev =  -m*9.8*S(ρ)*(R[-1].T) 
    #Find F
    f_new = newton(f, Π, J, M_prev, eps, h)
    F = rodrigues(f_new)
    
    #Find new orientation
    R_new = R*F
    
    #Find new Momentum
    M_new = -m*9.8*S(ρ)*(R_new[-1].T)
    Π_new = F.T*Π + h/2*(F.T*M_prev + M_new)
    
    return R_new, Π_new, f_new
    
def newton(f, Π, J, M, eps, h):
    
    f_new, val = update(f, Π, J, M, eps, h)
    
    while(np.linalg.norm(val)>eps):
        f_new, val = update(f_new, Π, J, M, eps, h)
        #print(np.linalg.norm(val))
    return f_new 

def update(f, Π, J, M, eps, h):
    norm = np.linalg.norm(f)
    
    # finding zero of sin(norm)Jf/norm + (1-cos(norm))fXJf/norm^2 - hΠ - h^2*M/2
    
    grad = (norm*cos(norm)-sin(norm))/norm**3 *J*f*f.T + sin(norm)/norm*J + (norm*sin(norm)+2*(1-cos(norm)))/norm**4* S(f)*J*f*f.T + (1 - cos(norm))/norm**2* (S(f)*J - S(J*f))
    
    val = sin(norm)/norm *J*f + (1-cos(norm))/norm**2 *S(f)*J*f - h*Π - h**2/2*M
    
    nxt = f - np.linalg.inv(grad)*val 
    
    norm = np.linalg.norm(nxt)
    val_nxt  = sin(norm)/norm *J*nxt + (1-cos(norm))/norm**2 *S(nxt)*J*nxt - h*Π - h**2/2*M
    
    return nxt, val_nxt

def rodrigues(f):
    norm = np.linalg.norm(f)
    S_f = S(f)
    return np.diag([1, 1, 1]) + sin(norm)/norm*S_f + (1-cos(norm))/norm**2* S_f**2

def S(a):
    return np.matrix([[0, -a[-1], a[1]],
                    [a[-1], 0, -a[0]],
                    [-a[1], a[0], 0]])

# %% [markdown]
# ### RK4 Integrator

# %%
def RF4(R, Π, J, ρ, m, h):
    
    # Π is angular momentum in pendulum frame, transform it to momentum..
    # in inertial frame, as we know differential equations in inertial-frame 
    # dRΠ/dt = mgRρ × e3, dR/dt = RS(Ω)
    
    A = R*Π
 
    Rk1 = dR(R, A, J, h)
    Ak1 = dA(R, m, ρ, h)
    
    Rk2 = dR(R+0.5*Rk1, A+0.5*Ak1, J, h)
    Ak2 = dA(R+0.5*Rk1, m, ρ, h)
    
    Rk3 = dR(R+0.5*Rk2, A+0.5*Ak2, J, h)
    Ak3 = dA(R+0.5*Rk2, m, ρ, h)
    
    Rk4 = dR(R+Rk3, A+Ak3, J, h)
    Ak4 = dA(R+Rk3, m, ρ, h)
    
    R_new = R + (Rk1 + 2*Rk2 + 2*Rk3 + Rk4)/6
    A_new = A + (Ak1 + 2*Ak2 + 2*Ak3 + Ak4)/6
    Π_new = R_new.T*A_new
    
    return R_new, Π_new 

def dR(R, A, J, h):
    
    Π = R.T*A
    Ω = np.linalg.inv(J)*Π
    
    return h*R*S(Ω)
    
def dA(R, m, ρ, h):
    
    e_3 = np.matrix([[0], 
                     [0], 
                     [1]])
    
    return -h*m*9.81*S(R*ρ)*e_3

# %% [markdown]
# ### Helper functions to simulate precession

# %%
def position(θ):                                       #Initial position
    return np.matrix([[1, 0, 0],
               [0, cos(θ), -sin(θ)],    
               [0, sin(θ), cos(θ)]])

def ang_vlcty(p, n, s, θ):                             #Initial angular velocity in body frame 
    return np.matrix([[n], [sin(θ)*p], [cos(θ)*p + s]])

def inertia(I_0, I):                                 #Inertia J = tr(J_d)I - J_d
    return np.matrix(np.diag([I_0 + I, I_0 + I, 2*I_0]))


def ang_momntm(I_0, I, ω):                              #Angular momentum in body frame
    return np.matrix(np.diag([I_0, I_0, I]))*ω

# %% [markdown]
# ### Function to simulate Precession

# %%
## Caution: Make sure to define parameters required for integration a priori

def precession(p, n, s, θ, integrator, runtime):
    
    #Define initial conditions
    R = position(θ)
    ω = ang_vlcty(p, n, s, θ)
    J = inertia(I_0, I)
    Π = ang_momntm(I_0, I, ω)
    f = 1e-1*ω
    
    #Run the simulation and store values
    t = 0
    z = np.array(R*ρ)
    if integrator == 'Variational':
        while t<runtime:
            R, Π, f = VI(R, Π, f, J, ρ, m, eps, h)
            z = np.append(z, np.array(R*ρ), axis=1)
            t += h
    elif integrator == 'RF4':
        while t<runtime:
            R, Π = RF4(R, Π, J, ρ, m, h)
            z = np.append(z, np.array(R*ρ), axis=1)
            t += h
        
    #Get x, y, z co-ordinates
    X = z[0]
    Y = z[1]
    Z = z[2]
        
    return X, Y, Z

# %% [markdown]
# ### Function to draw required figure

# %%
class Arrow3D(FancyArrowPatch):
    def __init__(self, xs, ys, zs, *args, **kwargs):
        FancyArrowPatch.__init__(self, (0,0), (0,0), *args, **kwargs)
        self._verts3d = xs, ys, zs

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
        self.set_positions((xs[0],ys[0]),(xs[1],ys[1]))
        FancyArrowPatch.draw(self, renderer)

def draw_plot(X, Y, Z, lbl):
    # Creating figure
    fig = plt.figure(figsize = (10, 10))
    ax = plt.axes(projection ="3d")
    
    # Draw sphere
    r = 0.05
    u, v = np.mgrid[0:2 * np.pi:30j, 0:np.pi:20j]
    x = np.cos(u) * np.sin(v)
    y = np.sin(u) * np.sin(v)
    z = np.cos(v)
    ax.plot_surface(x, y, z, alpha = 0.5)
    
    # Draw gravity direction
    g = Arrow3D([-0.9, -0.9], [-0.9, -0.9], [0, -0.75], mutation_scale=20, lw=2, arrowstyle="-|>", color='black', label = 'gravity')
    
    ax.add_artist(g)
    
    # Creating plot
    ax.plot3D(X, Y, Z, color = 'red', label = lbl)

    ax.set_xlim3d(-1, 1)
    ax.set_ylim3d(-1, 1)
    ax.set_zlim3d(-1, 1)
    ax.set_xlabel('X-axis', fontsize = 20)
    ax.set_ylabel('Y-axis', fontsize = 20)
    ax.set_zlabel('Z-axis', fontsize = 20)
    ax.tick_params(axis='both', which='major', labelsize=7)

    ax.legend(loc = 2,fontsize = 15)
    # show plot
    plt.show()
    

# Seperate function was created to allow precession parameters 
def draw_precession_plot(p, n, s, θ, integrator, runtime, lbl):
    X, Y, Z = precession(p, n, s, θ, integrator, runtime)
    draw_plot(X, Y, Z, lbl)

# %% [markdown]
# ### Animation Function

# %%
def animate_precession(X, Y, Z, lbl):
    # Creating figure
    fig = plt.figure(figsize = (10, 10))
    ax = plt.axes(projection ="3d")
    
    # Draw sphere
    r = 0.05
    u, v = np.mgrid[0:2 * np.pi:30j, 0:np.pi:20j]
    x = np.cos(u) * np.sin(v)
    y = np.sin(u) * np.sin(v)
    z = np.cos(v)
    ax.plot_surface(x, y, z, alpha = 0.5)
    
    # Draw gravity direction
    g = Arrow3D([-0.9, -0.9], [-0.9, -0.9], [0, -0.75], mutation_scale=20, lw=2, arrowstyle="-|>", color='black', label = 'gravity')
    
    ax.add_artist(g)
 
    # Creating plot
    line = ax.plot3D(X, Y, Z, color = 'red', label = lbl)[0]
    ax.set_xlim3d(-1, 1)
    ax.set_ylim3d(-1, 1)
    ax.set_zlim3d(-1, 1)
    ax.set_xlabel('X-axis', fontsize = 20)
    ax.set_ylabel('Y-axis', fontsize = 20)
    ax.set_zlabel('Z-axis', fontsize = 20)
    ax.tick_params(axis='both', which='major', labelsize=7)

    ax.legend(loc = 2,fontsize = 15)
    
    def update(num, x, y, z, line):
        line.set_xdata(x[:num])
        line.set_ydata(y[:num])
        line.set_3d_properties(z[:num])
        return line,
    
    ani = animation.FuncAnimation(fig, update, len(X), fargs=[X, Y, Z, line], interval=100, blit=True)
    
    return ani

# %% [markdown]
# ## Define Parameters

# %% [markdown]
# ### Function Parameters

# %%
eps = 1e-14   #Accepted error in Newton's method
h = 1e-1      #Time step
runtime = 30

# %% [markdown]
# ### Inertia & all

# %%
m = 1
ρ = np.matrix([[0], [0], [1]])
I_0 = 2   #I_xx, I_yy
I = 1     #I_zz

# %% [markdown]
# ### Initial conditions

# %% [markdown]
# ![title](precession.JPG)

# %%
#nutation
θ = 60*pi/180          
#precession rate
p = 1e-1
#spin rate
s = 1e1 
#nutation rate
n = 1e-2

# %% [markdown]
# ## Variational Integrator

# %%
X, Y, Z = precession(p, n, s, θ, 'Variational', runtime)

# %% [markdown]
# ### Draw  plot

# %%
draw_plot(X, Y, Z, 'Variational Integrator')

# %% [markdown]
# ### Animation

# %%
anim = animate_precession(X, Y, Z, 'Variational Integrator')
anim
# Out:
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Interactive plot

# %%
interact(draw_precession_plot, p = FloatSlider(min=0, max=pi, step=1e-1), n = FloatSlider(min=0, max=1, step=1e-2), s = FloatSlider(min=1, max=1e2, step=1), θ = FloatSlider(min = 0, max = pi/2, step = 1e-1), integrator = ['Variational', 'RF4'], runtime = fixed(20), lbl = fixed('Integrator'))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='p', max=3.141592653589793), FloatSlider(value=0.0, description='n', max=1.0, step=0.01), FloatSlider(value=1.0, description='s', min=1.0, step=1.0), FloatSlider(value=0.0, description='θ', max=1.5707963267948966), Dropdown(description='integrator', options=('Variational', 'RF4'), value='Variational'), Output()), _dom_classes=('widget-interact',))
# <function __main__.draw_precession_plot>

# %% [markdown]
# p = (0, π)          #precession rate <br>
# n = (0, 1)           #nutation rate <br>
# s = (1, 1e2)         #spin rate  <br>
# $\theta$ = (0, π/2)  #nutation   <br>
# runtime = 30
